# %% [markdown]
# #

# %%
# start of the projct

# %%
import pandas as pd

# %%
A1 = pd.read_csv("accepted.csv", low_memory = False)

# %%
A1
# Out:
#                                                        id  member_id  \
# 0                                                68407277        NaN
# 1                                                68355089        NaN
# 2                                                68341763        NaN
# 3                                                66310712        NaN
# 4                                                68476807        NaN
# ...                                                   ...        ...
# 2260696                                          88985880        NaN
# 2260697                                          88224441        NaN
# 2260698                                          88215728        NaN
# 2260699  Total amount funded in policy code 1: 1465324575        NaN
# 2260700   Total amount funded in policy code 2: 521953170        NaN
#
#          loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# ...

# %%
A2 = pd.read_csv("rejected.csv", low_memory = False)

# %%
A2
# Out:
#           Amount Requested Application Date                        Loan Title  \
# 0                   1000.0       2007-05-26  Wedding Covered but No Honeymoon
# 1                   1000.0       2007-05-26                Consolidating Debt
# 2                  11000.0       2007-05-27       Want to consolidate my debt
# 3                   6000.0       2007-05-27                           waksman
# 4                   1500.0       2007-05-27                            mdrigo
# ...                    ...              ...                               ...
# 27648736           10000.0       2016-12-31                Debt consolidation
# 27648737           10000.0       2016-12-31                            moving
# 27648738            1200.0       2016-12-31                             Other
# 27648739           25000.0       2016-12-31                debt_consolidation
# 27648740           15000.0       2016-12-31                          Business
#
# ...

# %%
A1
# Out:
#                                                        id  member_id  \
# 0                                                68407277        NaN
# 1                                                68355089        NaN
# 2                                                68341763        NaN
# 3                                                66310712        NaN
# 4                                                68476807        NaN
# ...                                                   ...        ...
# 2260696                                          88985880        NaN
# 2260697                                          88224441        NaN
# 2260698                                          88215728        NaN
# 2260699  Total amount funded in policy code 1: 1465324575        NaN
# 2260700   Total amount funded in policy code 2: 521953170        NaN
#
#          loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
A1.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade                    emp_title  \
# 0     13.99       123.03     C        C4                      leadman
# 1     11.99       820.28     C        C1                     Engineer
# 2     10.78       432.66     B        B4                 truck driver
# 3     14.85       829.90     C        C5  Information Systems Officer
# 4     22.45       289.91     F        F1          Contract Specialist
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
A3 = A1[["term", "loan_status", "dti", "purpose", "annual_inc", "int_rate"]]

# %% [markdown]
# A3

# %%
A3
# Out:
#                term  loan_status    dti             purpose  annual_inc  \
# 0         36 months   Fully Paid   5.91  debt_consolidation     55000.0
# 1         36 months   Fully Paid  16.06      small_business     65000.0
# 2         60 months   Fully Paid  10.78    home_improvement     63000.0
# 3         60 months      Current  17.06  debt_consolidation    110000.0
# 4         60 months   Fully Paid  25.37      major_purchase    104433.0
# ...             ...          ...    ...                 ...         ...
# 2260696   60 months      Current  12.75  debt_consolidation    227000.0
# 2260697   60 months  Charged Off  18.30  debt_consolidation    110000.0
# 2260698   60 months      Current  23.36  debt_consolidation     95000.0
# 2260699         NaN          NaN    NaN                 NaN         NaN
# 2260700         NaN          NaN    NaN                 NaN         NaN
#
#          int_rate
# 0           13.99
# 1           11.99
# 2           10.78
# 3           14.85
# ...

# %%
A3.isnull().sum()
# Out:
# term             33
# loan_status      33
# dti            1744
# purpose          33
# annual_inc       37
# int_rate         33
# dtype: int64

# %%
A3.dropna()
# Out:
#                term  loan_status    dti             purpose  annual_inc  \
# 0         36 months   Fully Paid   5.91  debt_consolidation     55000.0
# 1         36 months   Fully Paid  16.06      small_business     65000.0
# 2         60 months   Fully Paid  10.78    home_improvement     63000.0
# 3         60 months      Current  17.06  debt_consolidation    110000.0
# 4         60 months   Fully Paid  25.37      major_purchase    104433.0
# ...             ...          ...    ...                 ...         ...
# 2260694   60 months      Current  19.61    home_improvement     95000.0
# 2260695   60 months      Current  34.94  debt_consolidation    108000.0
# 2260696   60 months      Current  12.75  debt_consolidation    227000.0
# 2260697   60 months  Charged Off  18.30  debt_consolidation    110000.0
# 2260698   60 months      Current  23.36  debt_consolidation     95000.0
#
#          int_rate
# 0           13.99
# 1           11.99
# 2           10.78
# 3           14.85
# ...

# %%
A3.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2260696    False
# 2260697    False
# 2260698    False
# 2260699     True
# 2260700     True
# Length: 2260701, dtype: bool

# %%
A3.drop_duplicates()
# Out:
#                term  loan_status    dti             purpose  annual_inc  \
# 0         36 months   Fully Paid   5.91  debt_consolidation     55000.0
# 1         36 months   Fully Paid  16.06      small_business     65000.0
# 2         60 months   Fully Paid  10.78    home_improvement     63000.0
# 3         60 months      Current  17.06  debt_consolidation    110000.0
# 4         60 months   Fully Paid  25.37      major_purchase    104433.0
# ...             ...          ...    ...                 ...         ...
# 2260694   60 months      Current  19.61    home_improvement     95000.0
# 2260695   60 months      Current  34.94  debt_consolidation    108000.0
# 2260696   60 months      Current  12.75  debt_consolidation    227000.0
# 2260697   60 months  Charged Off  18.30  debt_consolidation    110000.0
# 2260698   60 months      Current  23.36  debt_consolidation     95000.0
#
#          int_rate
# 0           13.99
# 1           11.99
# 2           10.78
# 3           14.85
# ...

# %%
A3.to_csv("final_risk_guardian.csv", index = False)

# %%
A3.info
# Out:
# <bound method DataFrame.info of                term  loan_status    dti             purpose  annual_inc  \
# 0         36 months   Fully Paid   5.91  debt_consolidation     55000.0
# 1         36 months   Fully Paid  16.06      small_business     65000.0
# 2         60 months   Fully Paid  10.78    home_improvement     63000.0
# 3         60 months      Current  17.06  debt_consolidation    110000.0
# 4         60 months   Fully Paid  25.37      major_purchase    104433.0
# ...             ...          ...    ...                 ...         ...
# 2260696   60 months      Current  12.75  debt_consolidation    227000.0
# 2260697   60 months  Charged Off  18.30  debt_consolidation    110000.0
# 2260698   60 months      Current  23.36  debt_consolidation     95000.0
# 2260699         NaN          NaN    NaN                 NaN         NaN
# 2260700         NaN          NaN    NaN                 NaN         NaN
#
#          int_rate
# 0           13.99
# 1           11.99
# ...

# %%
A3.dtypes
# Out:
# term            object
# loan_status     object
# dti            float64
# purpose         object
# annual_inc     float64
# int_rate       float64
# dtype: object

# %%
A3.isnull().sum()
# Out:
# term             33
# loan_status      33
# dti            1744
# purpose          33
# annual_inc       37
# int_rate         33
# dtype: int64

# %%
A3.dropna()
# Out:
#                term  loan_status    dti             purpose  annual_inc  \
# 0         36 months   Fully Paid   5.91  debt_consolidation     55000.0
# 1         36 months   Fully Paid  16.06      small_business     65000.0
# 2         60 months   Fully Paid  10.78    home_improvement     63000.0
# 3         60 months      Current  17.06  debt_consolidation    110000.0
# 4         60 months   Fully Paid  25.37      major_purchase    104433.0
# ...             ...          ...    ...                 ...         ...
# 2260694   60 months      Current  19.61    home_improvement     95000.0
# 2260695   60 months      Current  34.94  debt_consolidation    108000.0
# 2260696   60 months      Current  12.75  debt_consolidation    227000.0
# 2260697   60 months  Charged Off  18.30  debt_consolidation    110000.0
# 2260698   60 months      Current  23.36  debt_consolidation     95000.0
#
#          int_rate
# 0           13.99
# 1           11.99
# 2           10.78
# 3           14.85
# ...

# %%
A3.isnull().sum()
# Out:
# term             33
# loan_status      33
# dti            1744
# purpose          33
# annual_inc       37
# int_rate         33
# dtype: int64

# %%
A3 = A3.dropna()

# %%
A3.isnull().sum()
# Out:
# term           0
# loan_status    0
# dti            0
# purpose        0
# annual_inc     0
# int_rate       0
# dtype: int64

# %%
A3.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2260694    False
# 2260695    False
# 2260696    False
# 2260697    False
# 2260698    False
# Length: 2258953, dtype: bool

# %%
A3 = A3.drop_duplicates()

# %%
A3.isnull().sum()
# Out:
# term           0
# loan_status    0
# dti            0
# purpose        0
# annual_inc     0
# int_rate       0
# dtype: int64

# %%
A3.to_csv("final_risk_guardian.csv", index = False)

# %%
A3.dtypes
# Out:
# term            object
# loan_status     object
# dti            float64
# purpose         object
# annual_inc     float64
# int_rate       float64
# dtype: object

# %%
# Remove ' months' and convert to integer
A3['term'] = A3['term'].str.replace(' months', '').astype(int)

# %%
A3.to_csv("final_risk_guardian.csv", index = False)

# %%
# Load your massive file
import pandas as pd
df = pd.read_csv('accepted.csv', low_memory = False)

# Save only the first 10,000 rows to a new file
df.head(10000).to_csv('loan_data_sample.csv', index=False)
